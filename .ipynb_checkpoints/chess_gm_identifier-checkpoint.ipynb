# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test/giri.jpg')
img.shape
# Out:
# (400, 400, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[141,  80, 163, 163]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (141, 80, 163, 163)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test/giri.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test/giri.jpg')
plt.imshow(cropped_image)

# %%
original_image = cv2.imread('./test/2.jpg')
plt.imshow(original_image)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped',
#  './dataset/GmAnish',
#  './dataset/GmDing',
#  './dataset/GmIan',
#  './dataset/GmLevon',
#  './dataset/GmMagnus']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
original_image = cv2.imread('./test/1.png')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test/3.jpeg')
plt.imshow(cropped_image)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".jpg"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# cropped
# GmAnish
# Generating cropped images in folder:  ./dataset/cropped/GmAnish
# GmDing
# Generating cropped images in folder:  ./dataset/cropped/GmDing
# GmIan
# Generating cropped images in folder:  ./dataset/cropped/GmIan
# GmLevon
# Generating cropped images in folder:  ./dataset/cropped/GmLevon
# GmMagnus
# Generating cropped images in folder:  ./dataset/cropped/GmMagnus

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'GmAnish': ['./dataset/cropped/GmAnish\\GmAnish1.jpg',
#   './dataset/cropped/GmAnish\\GmAnish10.jpg',
#   './dataset/cropped/GmAnish\\GmAnish11.jpg',
#   './dataset/cropped/GmAnish\\GmAnish12.jpg',
#   './dataset/cropped/GmAnish\\GmAnish13.jpg',
#   './dataset/cropped/GmAnish\\GmAnish14.jpg',
#   './dataset/cropped/GmAnish\\GmAnish15.jpg',
#   './dataset/cropped/GmAnish\\GmAnish16.jpg',
#   './dataset/cropped/GmAnish\\GmAnish17.jpg',
#   './dataset/cropped/GmAnish\\GmAnish18.jpg',
#   './dataset/cropped/GmAnish\\GmAnish19.jpg',
#   './dataset/cropped/GmAnish\\GmAnish2.jpg',
#   './dataset/cropped/GmAnish\\GmAnish20.jpg',
#   './dataset/cropped/GmAnish\\GmAnish21.jpg',
#   './dataset/cropped/GmAnish\\GmAnish22.jpg',
#   './dataset/cropped/GmAnish\\GmAnish23.jpg',
#   './dataset/cropped/GmAnish\\GmAnish24.jpg',
#   './dataset/cropped/GmAnish\\GmAnish25.jpg',
#   './dataset/cropped/GmAnish\\GmAnish3.jpg',
#   './dataset/cropped/GmAnish\\GmAnish4.jpg',
#   './dataset/cropped/GmAnish\\GmAnish5.jpg',
#   './dataset/cropped/GmAnish\\GmAnish6.jpg',
#   './dataset/cropped/GmAnish\\GmAnish7.jpg',
#   './dataset/cropped/GmAnish\\GmAnish8.jpg',
#   './dataset/cropped/GmAnish\\GmAnish9.jpg'],
#  'GmDing': ['./dataset/cropped/GmDing\\GmDing1.jpg',
#   './dataset/cropped/GmDing\\GmDing10.jpg',
#   './dataset/cropped/GmDing\\GmDing11.jpg',
#   './dataset/cropped/GmDing\\GmDing12.jpg',
#   './dataset/cropped/GmDing\\GmDing13.jpg',
#   './dataset/cropped/GmDing\\GmDing14.jpg',
#   './dataset/cropped/GmDing\\GmDing15.jpg',
#   './dataset/cropped/GmDing\\GmDing16.jpg',
#   './dataset/cropped/GmDing\\GmDing17.jpg',
#   './dataset/cropped/GmDing\\GmDing18.jpg',
#   './dataset/cropped/GmDing\\GmDing19.jpg',
#   './dataset/cropped/GmDing\\GmDing2.jpg',
#   './dataset/cropped/GmDing\\GmDing20.jpg',
#   './dataset/cropped/GmDing\\GmDing21.jpg',
#   './dataset/cropped/GmDing\\GmDing22.jpg',
#   './dataset/cropped/GmDing\\GmDing23.jpg',
#   './dataset/cropped/GmDing\\GmDing24.jpg',
#   './dataset/cropped/GmDing\\GmDing25.jpg',
#   './dataset/cropped/GmDing\\GmDing26.jpg',
#   './dataset/cropped/GmDing\\GmDing27.jpg',
#   './dataset/cropped/GmDing\\GmDing28.jpg',
#   './dataset/cropped/GmDing\\GmDing29.jpg',
#   './dataset/cropped/GmDing\\GmDing3.jpg',
#   './dataset/cropped/GmDing\\GmDing30.jpg',
#   './dataset/cropped/GmDing\\GmDing31.jpg',
#   './dataset/cropped/GmDing\\GmDing32.jpg',
#   './dataset/cropped/GmDing\\GmDing33.jpg',
#   './dataset/cropped/GmDing\\GmDing34.jpg',
#   './dataset/cropped/GmDing\\GmDing4.jpg',
#   './dataset/cropped/GmDing\\GmDing5.jpg',
#   './dataset/cropped/GmDing\\GmDing6.jpg',
#   './dataset/cropped/GmDing\\GmDing7.jpg',
#   './dataset/cropped/GmDing\\GmDing8.jpg',
#   './dataset/cropped/GmDing\\GmDing9.jpg'],
#  'GmIan': ['./dataset/cropped/GmIan\\GmIan1.jpg',
#   './dataset/cropped/GmIan\\GmIan10.jpg',
#   './dataset/cropped/GmIan\\GmIan11.jpg',
#   './dataset/cropped/GmIan\\GmIan12.jpg',
#   './dataset/cropped/GmIan\\GmIan13.jpg',
#   './dataset/cropped/GmIan\\GmIan14.jpg',
#   './dataset/cropped/GmIan\\GmIan15.jpg',
#   './dataset/cropped/GmIan\\GmIan16.jpg',
#   './dataset/cropped/GmIan\\GmIan17.jpg',
#   './dataset/cropped/GmIan\\GmIan18.jpg',
#   './dataset/cropped/GmIan\\GmIan19.jpg',
#   './dataset/cropped/GmIan\\GmIan2.jpg',
#   './dataset/cropped/GmIan\\GmIan20.jpg',
#   './dataset/cropped/GmIan\\GmIan21.jpg',
#   './dataset/cropped/GmIan\\GmIan22.jpg',
#   './dataset/cropped/GmIan\\GmIan23.jpg',
#   './dataset/cropped/GmIan\\GmIan24.jpg',
#   './dataset/cropped/GmIan\\GmIan25.jpg',
#   './dataset/cropped/GmIan\\GmIan26.jpg',
#   './dataset/cropped/GmIan\\GmIan27.jpg',
#   './dataset/cropped/GmIan\\GmIan28.jpg',
#   './dataset/cropped/GmIan\\GmIan29.jpg',
#   './dataset/cropped/GmIan\\GmIan3.jpg',
#   './dataset/cropped/GmIan\\GmIan30.jpg',
#   './dataset/cropped/GmIan\\GmIan31.jpg',
#   './dataset/cropped/GmIan\\GmIan32.jpg',
#   './dataset/cropped/GmIan\\GmIan33.jpg',
#   './dataset/cropped/GmIan\\GmIan34.jpg',
#   './dataset/cropped/GmIan\\GmIan35.jpg',
#   './dataset/cropped/GmIan\\GmIan36.jpg',
#   './dataset/cropped/GmIan\\GmIan37.jpg',
#   './dataset/cropped/GmIan\\GmIan38.jpg',
#   './dataset/cropped/GmIan\\GmIan39.jpg',
#   './dataset/cropped/GmIan\\GmIan4.jpg',
#   './dataset/cropped/GmIan\\GmIan40.jpg',
#   './dataset/cropped/GmIan\\GmIan41.jpg',
#   './dataset/cropped/GmIan\\GmIan42.jpg',
#   './dataset/cropped/GmIan\\GmIan43.jpg',
#   './dataset/cropped/GmIan\\GmIan44.jpg',
#   './dataset/cropped/GmIan\\GmIan45.jpg',
#   './dataset/cropped/GmIan\\GmIan46.jpg',
#   './dataset/cropped/GmIan\\GmIan47.jpg',
#   './dataset/cropped/GmIan\\GmIan48.jpg',
#   './dataset/cropped/GmIan\\GmIan5.jpg',
#   './dataset/cropped/GmIan\\GmIan6.jpg',
#   './dataset/cropped/GmIan\\GmIan7.jpg',
#   './dataset/cropped/GmIan\\GmIan8.jpg',
#   './dataset/cropped/GmIan\\GmIan9.jpg'],
#  'GmLevon': ['./dataset/cropped/GmLevon\\GmLevon1.jpg',
#   './dataset/cropped/GmLevon\\GmLevon10.jpg',
#   './dataset/cropped/GmLevon\\GmLevon11.jpg',
#   './dataset/cropped/GmLevon\\GmLevon12.jpg',
#   './dataset/cropped/GmLevon\\GmLevon13.jpg',
#   './dataset/cropped/GmLevon\\GmLevon14.jpg',
#   './dataset/cropped/GmLevon\\GmLevon15.jpg',
#   './dataset/cropped/GmLevon\\GmLevon16.jpg',
#   './dataset/cropped/GmLevon\\GmLevon17.jpg',
#   './dataset/cropped/GmLevon\\GmLevon18.jpg',
#   './dataset/cropped/GmLevon\\GmLevon19.jpg',
#   './dataset/cropped/GmLevon\\GmLevon2.jpg',
#   './dataset/cropped/GmLevon\\GmLevon20.jpg',
#   './dataset/cropped/GmLevon\\GmLevon21.jpg',
#   './dataset/cropped/GmLevon\\GmLevon22.jpg',
#   './dataset/cropped/GmLevon\\GmLevon23.jpg',
#   './dataset/cropped/GmLevon\\GmLevon24.jpg',
#   './dataset/cropped/GmLevon\\GmLevon25.jpg',
#   './dataset/cropped/GmLevon\\GmLevon26.jpg',
#   './dataset/cropped/GmLevon\\GmLevon27.jpg',
#   './dataset/cropped/GmLevon\\GmLevon28.jpg',
#   './dataset/cropped/GmLevon\\GmLevon29.jpg',
#   './dataset/cropped/GmLevon\\GmLevon3.jpg',
#   './dataset/cropped/GmLevon\\GmLevon30.jpg',
#   './dataset/cropped/GmLevon\\GmLevon31.jpg',
#   './dataset/cropped/GmLevon\\GmLevon32.jpg',
#   './dataset/cropped/GmLevon\\GmLevon33.jpg',
#   './dataset/cropped/GmLevon\\GmLevon34.jpg',
#   './dataset/cropped/GmLevon\\GmLevon35.jpg',
#   './dataset/cropped/GmLevon\\GmLevon36.jpg',
#   './dataset/cropped/GmLevon\\GmLevon37.jpg',
#   './dataset/cropped/GmLevon\\GmLevon38.jpg',
#   './dataset/cropped/GmLevon\\GmLevon39.jpg',
#   './dataset/cropped/GmLevon\\GmLevon4.jpg',
#   './dataset/cropped/GmLevon\\GmLevon40.jpg',
#   './dataset/cropped/GmLevon\\GmLevon41.jpg',
#   './dataset/cropped/GmLevon\\GmLevon42.jpg',
#   './dataset/cropped/GmLevon\\GmLevon43.jpg',
#   './dataset/cropped/GmLevon\\GmLevon44.jpg',
#   './dataset/cropped/GmLevon\\GmLevon45.jpg',
#   './dataset/cropped/GmLevon\\GmLevon46.jpg',
#   './dataset/cropped/GmLevon\\GmLevon47.jpg',
#   './dataset/cropped/GmLevon\\GmLevon48.jpg',
#   './dataset/cropped/GmLevon\\GmLevon49.jpg',
#   './dataset/cropped/GmLevon\\GmLevon5.jpg',
#   './dataset/cropped/GmLevon\\GmLevon6.jpg',
#   './dataset/cropped/GmLevon\\GmLevon7.jpg',
#   './dataset/cropped/GmLevon\\GmLevon8.jpg',
#   './dataset/cropped/GmLevon\\GmLevon9.jpg'],
#  'GmMagnus': ['./dataset/cropped/GmMagnus\\GmMagnus1.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus10.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus11.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus12.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus13.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus14.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus15.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus16.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus17.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus18.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus19.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus2.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus20.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus21.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus22.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus23.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus24.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus25.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus26.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus27.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus28.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus3.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus4.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus5.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus6.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus7.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus8.jpg',
#   './dataset/cropped/GmMagnus\\GmMagnus9.jpg']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'GmAnish': 0, 'GmDing': 1, 'GmIan': 2, 'GmLevon': 3, 'GmMagnus': 4}

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H
