# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test/giri.jpg')
img.shape
# Out:
# (400, 400, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (400, 400)

# %%
gray
# Out:
# array([[65, 65, 65, ..., 82, 83, 83],
#        [65, 65, 65, ..., 86, 86, 86],
#        [64, 64, 64, ..., 91, 92, 92],
#        ...,
#        [11, 11, 12, ..., 11, 11, 11],
#        [11, 11, 12, ..., 11, 11, 11],
#        [11, 11, 12, ..., 11, 11, 11]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[141,  80, 163, 163]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (141, 80, 163, 163)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (163, 163, 3)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test/anishg.png')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test/anishg.png')
plt.imshow(cropped_image)

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/GmAnish',
#  './dataset/GmDing',
#  './dataset/GmIan',
#  './dataset/GmLevon',
#  './dataset/GmMagnus']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/GmAnish
# Generating cropped images in folder:  ./dataset/cropped/GmDing
# Generating cropped images in folder:  ./dataset/cropped/GmIan
# Generating cropped images in folder:  ./dataset/cropped/GmLevon
# Generating cropped images in folder:  ./dataset/cropped/GmMagnus

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'GmAnish': ['./dataset/cropped/GmAnish\\GmAnish1.png',
#   './dataset/cropped/GmAnish\\GmAnish10.png',
#   './dataset/cropped/GmAnish\\GmAnish11.png',
#   './dataset/cropped/GmAnish\\GmAnish12.png',
#   './dataset/cropped/GmAnish\\GmAnish13.png',
#   './dataset/cropped/GmAnish\\GmAnish14.png',
#   './dataset/cropped/GmAnish\\GmAnish15.png',
#   './dataset/cropped/GmAnish\\GmAnish16.png',
#   './dataset/cropped/GmAnish\\GmAnish17.png',
#   './dataset/cropped/GmAnish\\GmAnish18.png',
#   './dataset/cropped/GmAnish\\GmAnish19.png',
#   './dataset/cropped/GmAnish\\GmAnish2.png',
#   './dataset/cropped/GmAnish\\GmAnish20.png',
#   './dataset/cropped/GmAnish\\GmAnish21.png',
#   './dataset/cropped/GmAnish\\GmAnish22.png',
#   './dataset/cropped/GmAnish\\GmAnish23.png',
#   './dataset/cropped/GmAnish\\GmAnish24.png',
#   './dataset/cropped/GmAnish\\GmAnish25.png',
#   './dataset/cropped/GmAnish\\GmAnish3.png',
#   './dataset/cropped/GmAnish\\GmAnish4.png',
#   './dataset/cropped/GmAnish\\GmAnish5.png',
#   './dataset/cropped/GmAnish\\GmAnish6.png',
#   './dataset/cropped/GmAnish\\GmAnish7.png',
#   './dataset/cropped/GmAnish\\GmAnish8.png',
#   './dataset/cropped/GmAnish\\GmAnish9.png'],
#  'GmDing': ['./dataset/cropped/GmDing\\GmDing1.png',
#   './dataset/cropped/GmDing\\GmDing10.png',
#   './dataset/cropped/GmDing\\GmDing11.png',
#   './dataset/cropped/GmDing\\GmDing12.png',
#   './dataset/cropped/GmDing\\GmDing13.png',
#   './dataset/cropped/GmDing\\GmDing14.png',
#   './dataset/cropped/GmDing\\GmDing15.png',
#   './dataset/cropped/GmDing\\GmDing16.png',
#   './dataset/cropped/GmDing\\GmDing17.png',
#   './dataset/cropped/GmDing\\GmDing18.png',
#   './dataset/cropped/GmDing\\GmDing19.png',
#   './dataset/cropped/GmDing\\GmDing20.png',
#   './dataset/cropped/GmDing\\GmDing21.png',
#   './dataset/cropped/GmDing\\GmDing22.png',
#   './dataset/cropped/GmDing\\GmDing23.png',
#   './dataset/cropped/GmDing\\GmDing24.png',
#   './dataset/cropped/GmDing\\GmDing25.png',
#   './dataset/cropped/GmDing\\GmDing26.png',
#   './dataset/cropped/GmDing\\GmDing27.png',
#   './dataset/cropped/GmDing\\GmDing28.png',
#   './dataset/cropped/GmDing\\GmDing29.png',
#   './dataset/cropped/GmDing\\GmDing3.png',
#   './dataset/cropped/GmDing\\GmDing30.png',
#   './dataset/cropped/GmDing\\GmDing31.png',
#   './dataset/cropped/GmDing\\GmDing32.png',
#   './dataset/cropped/GmDing\\GmDing33.png',
#   './dataset/cropped/GmDing\\GmDing4.png',
#   './dataset/cropped/GmDing\\GmDing5.png',
#   './dataset/cropped/GmDing\\GmDing6.png',
#   './dataset/cropped/GmDing\\GmDing7.png',
#   './dataset/cropped/GmDing\\GmDing8.png',
#   './dataset/cropped/GmDing\\GmDing9.png'],
#  'GmIan': ['./dataset/cropped/GmIan\\GmIan1.png',
#   './dataset/cropped/GmIan\\GmIan10.png',
#   './dataset/cropped/GmIan\\GmIan11.png',
#   './dataset/cropped/GmIan\\GmIan12.png',
#   './dataset/cropped/GmIan\\GmIan13.png',
#   './dataset/cropped/GmIan\\GmIan14.png',
#   './dataset/cropped/GmIan\\GmIan15.png',
#   './dataset/cropped/GmIan\\GmIan16.png',
#   './dataset/cropped/GmIan\\GmIan17.png',
#   './dataset/cropped/GmIan\\GmIan18.png',
#   './dataset/cropped/GmIan\\GmIan19.png',
#   './dataset/cropped/GmIan\\GmIan2.png',
#   './dataset/cropped/GmIan\\GmIan20.png',
#   './dataset/cropped/GmIan\\GmIan21.png',
#   './dataset/cropped/GmIan\\GmIan22.png',
#   './dataset/cropped/GmIan\\GmIan23.png',
#   './dataset/cropped/GmIan\\GmIan24.png',
#   './dataset/cropped/GmIan\\GmIan25.png',
#   './dataset/cropped/GmIan\\GmIan26.png',
#   './dataset/cropped/GmIan\\GmIan27.png',
#   './dataset/cropped/GmIan\\GmIan28.png',
#   './dataset/cropped/GmIan\\GmIan29.png',
#   './dataset/cropped/GmIan\\GmIan3.png',
#   './dataset/cropped/GmIan\\GmIan30.png',
#   './dataset/cropped/GmIan\\GmIan31.png',
#   './dataset/cropped/GmIan\\GmIan32.png',
#   './dataset/cropped/GmIan\\GmIan33.png',
#   './dataset/cropped/GmIan\\GmIan34.png',
#   './dataset/cropped/GmIan\\GmIan35.png',
#   './dataset/cropped/GmIan\\GmIan36.png',
#   './dataset/cropped/GmIan\\GmIan37.png',
#   './dataset/cropped/GmIan\\GmIan38.png',
#   './dataset/cropped/GmIan\\GmIan39.png',
#   './dataset/cropped/GmIan\\GmIan4.png',
#   './dataset/cropped/GmIan\\GmIan40.png',
#   './dataset/cropped/GmIan\\GmIan41.png',
#   './dataset/cropped/GmIan\\GmIan42.png',
#   './dataset/cropped/GmIan\\GmIan43.png',
#   './dataset/cropped/GmIan\\GmIan44.png',
#   './dataset/cropped/GmIan\\GmIan45.png',
#   './dataset/cropped/GmIan\\GmIan46.png',
#   './dataset/cropped/GmIan\\GmIan47.png',
#   './dataset/cropped/GmIan\\GmIan48.png',
#   './dataset/cropped/GmIan\\GmIan5.png',
#   './dataset/cropped/GmIan\\GmIan6.png',
#   './dataset/cropped/GmIan\\GmIan7.png',
#   './dataset/cropped/GmIan\\GmIan8.png',
#   './dataset/cropped/GmIan\\GmIan9.png'],
#  'GmLevon': ['./dataset/cropped/GmLevon\\GmLevon1.png',
#   './dataset/cropped/GmLevon\\GmLevon10.png',
#   './dataset/cropped/GmLevon\\GmLevon11.png',
#   './dataset/cropped/GmLevon\\GmLevon12.png',
#   './dataset/cropped/GmLevon\\GmLevon13.png',
#   './dataset/cropped/GmLevon\\GmLevon14.png',
#   './dataset/cropped/GmLevon\\GmLevon15.png',
#   './dataset/cropped/GmLevon\\GmLevon16.png',
#   './dataset/cropped/GmLevon\\GmLevon17.png',
#   './dataset/cropped/GmLevon\\GmLevon18.png',
#   './dataset/cropped/GmLevon\\GmLevon19.png',
#   './dataset/cropped/GmLevon\\GmLevon2.png',
#   './dataset/cropped/GmLevon\\GmLevon20.png',
#   './dataset/cropped/GmLevon\\GmLevon21.png',
#   './dataset/cropped/GmLevon\\GmLevon22.png',
#   './dataset/cropped/GmLevon\\GmLevon23.png',
#   './dataset/cropped/GmLevon\\GmLevon24.png',
#   './dataset/cropped/GmLevon\\GmLevon25.png',
#   './dataset/cropped/GmLevon\\GmLevon26.png',
#   './dataset/cropped/GmLevon\\GmLevon27.png',
#   './dataset/cropped/GmLevon\\GmLevon28.png',
#   './dataset/cropped/GmLevon\\GmLevon29.png',
#   './dataset/cropped/GmLevon\\GmLevon3.png',
#   './dataset/cropped/GmLevon\\GmLevon30.png',
#   './dataset/cropped/GmLevon\\GmLevon31.png',
#   './dataset/cropped/GmLevon\\GmLevon32.png',
#   './dataset/cropped/GmLevon\\GmLevon33.png',
#   './dataset/cropped/GmLevon\\GmLevon34.png',
#   './dataset/cropped/GmLevon\\GmLevon35.png',
#   './dataset/cropped/GmLevon\\GmLevon36.png',
#   './dataset/cropped/GmLevon\\GmLevon37.png',
#   './dataset/cropped/GmLevon\\GmLevon38.png',
#   './dataset/cropped/GmLevon\\GmLevon39.png',
#   './dataset/cropped/GmLevon\\GmLevon4.png',
#   './dataset/cropped/GmLevon\\GmLevon40.png',
#   './dataset/cropped/GmLevon\\GmLevon41.png',
#   './dataset/cropped/GmLevon\\GmLevon42.png',
#   './dataset/cropped/GmLevon\\GmLevon43.png',
#   './dataset/cropped/GmLevon\\GmLevon44.png',
#   './dataset/cropped/GmLevon\\GmLevon45.png',
#   './dataset/cropped/GmLevon\\GmLevon46.png',
#   './dataset/cropped/GmLevon\\GmLevon47.png',
#   './dataset/cropped/GmLevon\\GmLevon48.png',
#   './dataset/cropped/GmLevon\\GmLevon49.png',
#   './dataset/cropped/GmLevon\\GmLevon5.png',
#   './dataset/cropped/GmLevon\\GmLevon6.png',
#   './dataset/cropped/GmLevon\\GmLevon7.png',
#   './dataset/cropped/GmLevon\\GmLevon8.png',
#   './dataset/cropped/GmLevon\\GmLevon9.png'],
#  'GmMagnus': ['./dataset/cropped/GmMagnus\\GmMagnus1.png',
#   './dataset/cropped/GmMagnus\\GmMagnus10.png',
#   './dataset/cropped/GmMagnus\\GmMagnus11.png',
#   './dataset/cropped/GmMagnus\\GmMagnus12.png',
#   './dataset/cropped/GmMagnus\\GmMagnus13.png',
#   './dataset/cropped/GmMagnus\\GmMagnus14.png',
#   './dataset/cropped/GmMagnus\\GmMagnus15.png',
#   './dataset/cropped/GmMagnus\\GmMagnus16.png',
#   './dataset/cropped/GmMagnus\\GmMagnus17.png',
#   './dataset/cropped/GmMagnus\\GmMagnus18.png',
#   './dataset/cropped/GmMagnus\\GmMagnus19.png',
#   './dataset/cropped/GmMagnus\\GmMagnus2.png',
#   './dataset/cropped/GmMagnus\\GmMagnus20.png',
#   './dataset/cropped/GmMagnus\\GmMagnus21.png',
#   './dataset/cropped/GmMagnus\\GmMagnus22.png',
#   './dataset/cropped/GmMagnus\\GmMagnus23.png',
#   './dataset/cropped/GmMagnus\\GmMagnus24.png',
#   './dataset/cropped/GmMagnus\\GmMagnus25.png',
#   './dataset/cropped/GmMagnus\\GmMagnus26.png',
#   './dataset/cropped/GmMagnus\\GmMagnus27.png',
#   './dataset/cropped/GmMagnus\\GmMagnus28.png',
#   './dataset/cropped/GmMagnus\\GmMagnus3.png',
#   './dataset/cropped/GmMagnus\\GmMagnus4.png',
#   './dataset/cropped/GmMagnus\\GmMagnus5.png',
#   './dataset/cropped/GmMagnus\\GmMagnus6.png',
#   './dataset/cropped/GmMagnus\\GmMagnus7.png',
#   './dataset/cropped/GmMagnus\\GmMagnus8.png',
#   './dataset/cropped/GmMagnus\\GmMagnus9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'GmAnish': 0, 'GmDing': 1, 'GmIan': 2, 'GmLevon': 3, 'GmMagnus': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[  3],
#        [  2],
#        [  4],
#        ...,
#        [ 54],
#        [  2],
#        [252]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (182, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.6521739130434783

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         6
#            1       0.83      0.56      0.67         9
#            2       0.71      0.71      0.71        14
#            3       0.42      0.89      0.57         9
#            4       1.00      0.38      0.55         8
#
#     accuracy                           0.65        46
#    macro avg       0.79      0.64      0.66        46
# weighted avg       0.77      0.65      0.66        46

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.647619
# 1        random_forest    0.382011
# 2  logistic_regression    0.625397
#
#                                    best_params
# 0       {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 5}
# 2                 {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=5))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.6956521739130435

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.34782608695652173

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.6521739130434783

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 6,  0,  0,  0,  0],
#        [ 0,  5,  1,  3,  0],
#        [ 1,  0, 10,  3,  0],
#        [ 0,  1,  2,  6,  0],
#        [ 0,  1,  1,  1,  5]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'GmAnish': 0, 'GmDing': 1, 'GmIan': 2, 'GmLevon': 3, 'GmMagnus': 4}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\khera\anaconda\lib\site-packages (1.1.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
